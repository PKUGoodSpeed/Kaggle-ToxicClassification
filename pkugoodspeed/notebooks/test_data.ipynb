# %%
import pandas as pd

# %%
df = pd.read_csv('../data/train.csv')

# %%
from IPython.display import display

# %%
display(df[100:])
# Out:
#                       id                                       comment_text  \
# 100     003f698d06c9b180  However, the Moonlite edit noted by golden dap...
# 101     003fa0c68deca750  Check the following websites:\n\nhttp://www.ir...
# 102     0040017ef6277334  i can't believe no one has already put up this...
# 103     004176f28a17bf45  "\n\nWell, after I asked you to provide the di...
# 104     0044cf18cc2655b3  What page shoudld there be for important chara...
# 105     00472b8e2d38d1ea         A pair of jew-hating weiner nazi schmucks.
# 106     00480b6e1f19601b  I tend to think that when the list is longer t...
# 107     0048de0c9422f64f  "\n\n What's up with this? \n""If you are a re...
# 108     0048e4ed8a0af433  I'm not vandalizing  \n\nI'm just having fun m...
# 109     004a23742282fee4  Welcome to Wikipedia ! [bla] Discover Ekopedia...
# 110     004a789c03eda830  Including some appropriate mention of the Solo...
# ...

# %%
import string

# %%
punc = set(string.punctuation)
print(len(punc))
p = list(punc)
print(p)
# Out:
# 32
# ['/', '$', '#', '*', '^', '|', '=', '!', ',', '}', "'", ')', '_', '{', '.', '%', '&', '(', '[', ']', ';', '"', '~', '>', '\\', '<', ':', '+', '`', '-', '?', '@']

# %%
symbols="~`!@#$%^&*()_+-=`¡™£¢∞§¶•–≠∑´®†¥¨ˆ“‘«ß©˙˚¬…≈ç√˜≤≥÷;\':\",./<>?[]\{}|\n\t"
symbol_list = [c for c in symbols]
print(symbol_list)
# Out:
# ['~', '`', '!', '@', '#', '$', '%', '^', '&', '*', '(', ')', '_', '+', '-', '=', '`', '¡', '™', '£', '¢', '∞', '§', '¶', '•', '–', '≠', '∑', '´', '®', '†', '¥', '¨', 'ˆ', '“', '‘', '«', 'ß', '©', '˙', '˚', '¬', '…', '≈', 'ç', '√', '˜', '≤', '≥', '÷', ';', "'", ':', '"', ',', '.', '/', '<', '>', '?', '[', ']', '\\', '{', '}', '|', '\n', '\t']

# %%
p += symbol_list

# %%
punc = set(p)

# %%
print(len(punc))
# Out:
# 67

# %%
def rmPunc(sent):
    for ch in punc:
        sent = sent.replace(ch, ' ')
    return sent
def rmMultiSpace(sent):
    return re.sub(' +',' ', sent)

# %%
import re

# %%
from multiprocessing import Pool

# %%
pool = Pool(4)
# %time df.comment_text = pool.map(rmPunc, df.comment_text.str.lower())
# %time df.comment_text = pool.map(rmMultiSpace, df.comment_text.str.lower())
pool.close()
pool.join()
# Out:
# CPU times: user 813 ms, sys: 556 ms, total: 1.37 s
# Wall time: 4.08 s
# CPU times: user 686 ms, sys: 265 ms, total: 951 ms
# Wall time: 4.65 s

# %%
display(df[100:])
# Out:
#                       id                                       comment_text  \
# 100     003f698d06c9b180  however the moonlite edit noted by golden daph...
# 101     003fa0c68deca750  check the following websites http www irancham...
# 102     0040017ef6277334  i can t believe no one has already put up this...
# 103     004176f28a17bf45   well after i asked you to provide the diffs w...
# 104     0044cf18cc2655b3  what page shoudld there be for important chara...
# 105     00472b8e2d38d1ea         a pair of jew hating weiner nazi schmucks
# 106     00480b6e1f19601b  i tend to think that when the list is longer t...
# 107     0048de0c9422f64f   what s up with this if you are a religiously ...
# 108     0048e4ed8a0af433  i m not vandalizing i m just having fun man yo...
# 109     004a23742282fee4  welcome to wikipedia bla discover ekopedia the...
# 110     004a789c03eda830  including some appropriate mention of the solo...
# ...

# %%
df.to_csv('new_train.csv', index=False)

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(df.comment_text.tolist(), size=100, window=5, min_count=5, workers=4)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings).First item here is instead plain <class 'str'>.
